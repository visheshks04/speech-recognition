# %%
import librosa
import matplotlib.pyplot as plt
# %matplotlib inline
aud = librosa.load('data/1 Algorithmic Thinking Peak Finding.webm')
plt.plot(aud[0])
# Out:
# /home/vishesh/.local/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
from scipy.io import wavfile
wavfile.write('test.wav', aud[1], aud[0])
